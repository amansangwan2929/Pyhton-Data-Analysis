# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/amans/Downloads/Car.csv')

# %%
df.shape
# Out:
# (8127, 14)

# %%
df.head()
# Out:
#    Unnamed: 0                          name  year  selling_price  km_driven  \
# 0           0        Maruti Swift Dzire VDI  2014         450000     145500
# 1           1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2           2      Honda City 2017-2020 EXi  2006         158000     140000
# 3           3     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4           4        Maruti Swift VXI BSIII  2007         130000     120000
#
#      fuel seller_type transmission         owner     mileage   engine  \
# 0  Diesel  Individual       Manual   First Owner   23.4 kmpl  1248 CC
# 1  Diesel  Individual       Manual  Second Owner  21.14 kmpl  1498 CC
# 2  Petrol  Individual       Manual   Third Owner   17.7 kmpl  1497 CC
# 3  Diesel  Individual       Manual   First Owner   23.0 kmpl  1396 CC
# 4  Petrol  Individual       Manual   First Owner   16.1 kmpl  1298 CC
#
#     max_power                    torque  seats
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8127 entries, 0 to 8126
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8127 non-null   int64
#  1   name           8127 non-null   object
#  2   year           8127 non-null   int64
#  3   selling_price  8127 non-null   int64
#  4   km_driven      8127 non-null   int64
#  5   fuel           8127 non-null   object
#  6   seller_type    8127 non-null   object
#  7   transmission   8127 non-null   object
#  8   owner          8127 non-null   object
#  9   mileage        7906 non-null   object
#  10  engine         7906 non-null   object
#  11  max_power      7912 non-null   object
#  12  torque         7906 non-null   object
#  13  seats          7906 non-null   float64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 889.0+ KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           221
# seats            221
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#                           name    fuel seller_type transmission        owner  \
# count                     7906    7906        7906         7906         7906
# unique                    1982       4           3            2            6
# top     Maruti Swift Dzire VDI  Diesel  Individual       Manual  First Owner
# freq                       129    4299        6563         6865         5215
#
#           mileage   engine max_power          torque
# count        7906     7906      7906            7906
# unique        393      122       321             441
# top     18.9 kmpl  1248 CC    74 bhp  190Nm@ 2000rpm
# freq          225     1017       377             530

# %%
df.describe()
# Out:
#         Unnamed: 0         year  selling_price     km_driven        seats
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   4068.712750  2013.983936   6.498137e+05  6.918866e+04     5.416393
# std    2345.357079     3.863695   8.135827e+05  5.679230e+04     0.959208
# min       0.000000  1994.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2036.250000  2012.000000   2.700000e+05  3.500000e+04     5.000000
# 50%    4075.500000  2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    6100.000000  2017.000000   6.900000e+05  9.542500e+04     5.000000
# max    8126.000000  2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
df.drop('torque', axis=1, inplace=True)

# %%
df.head(10)
# Out:
#    Unnamed: 0                                  name  year  selling_price  \
# 0           0                Maruti Swift Dzire VDI  2014         450000
# 1           1          Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2           2              Honda City 2017-2020 EXi  2006         158000
# 3           3             Hyundai i20 Sportz Diesel  2010         225000
# 4           4                Maruti Swift VXI BSIII  2007         130000
# 5           5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# 6           6          Maruti Wagon R LXI DUO BSIII  2007          96000
# 7           7                    Maruti 800 DX BSII  2001          45000
# 8           8                      Toyota Etios VXD  2011         350000
# 9           9  Ford Figo Diesel Celebration Edition  2013         200000
#
#    km_driven    fuel seller_type transmission         owner     mileage  \
# 0     145500  Diesel  Individual       Manual   First Owner   23.4 kmpl
# ...

# %%
df['seats'].unique()
df['seats'].dtype
df['seats'].value_counts()
# Out:
# 5.0     6254
# 7.0     1120
# 8.0      235
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: seats, dtype: int64

# %%
numeric = df[['max_power','engine','mileage','km_driven','selling_price','year']]
categorical= df[['name','fuel','seller_type','transmission','owner','seats']]
numeric.corr()
# Out:
# C:\Users\amans\AppData\Local\Temp\ipykernel_15972\2722891767.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   numeric.corr()
#                km_driven  selling_price      year
# km_driven       1.000000      -0.222126 -0.428487
# selling_price  -0.222126       1.000000  0.412278
# year           -0.428487       0.412278  1.000000

# %%
sns.heatmap(numeric.corr())
plt.show()
# Out:
# C:\Users\amans\AppData\Local\Temp\ipykernel_15972\241603900.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(numeric.corr())

# %%
sns.countplot(x = 'owner' , data= df)
sns.set(rc={'figure.figsize':(15,9)})

# %%
mileage_test=df.groupby(['year'],as_index=False)['selling_price'].sum().sort_values(by='selling_price',ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = mileage_test,x = 'year' , y = 'selling_price')
# Out:
# <Axes: xlabel='year', ylabel='selling_price'>

# %% [markdown]
# In above graph the more car selling in 2019.
